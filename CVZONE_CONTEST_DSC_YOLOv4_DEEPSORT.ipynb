# %%
# !git clone https://github.com/Mohak-CODING-HEAVEN/Scrape-Car-Counting-Yolov4-DeepSort.git
# Out:
# Cloning into 'Scrape-Car-Counting-Yolov4-DeepSort'...
# remote: Enumerating objects: 194, done.
# remote: Counting objects: 100% (194/194), done.
# remote: Compressing objects: 100% (186/186), done.
# remote: Total 194 (delta 16), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (194/194), 34.40 MiB | 18.34 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# %cd /content/Scrape-Car-Counting-Yolov4-DeepSort/
# !pip install -r requirements-gpu.txt
# Out:
# /content/Scrape-Car-Counting-Yolov4-DeepSort

# %% [markdown]
# **Download the Following Files and Paste as Follows**
#
# 1.
# https://drive.google.com/file/d/1hfjGVlzlf-pts4__94JmzJxH3M2zkd4a/view?usp=sharing
# <->Yolov4 Custom Weights!!
# Paste it in <-> /content/Scrape-Car-Counting-Yolov4-DeepSort/data
#
# 2.
# https://drive.google.com/u/0/uc?export=download&confirm=GQzn&id=1xttdxqHIYex0iwm6jfUUGE4QmNMCAU9o <-> Saved Model <-> Paste in /content/Scrape-Car-Counting-Yolov4-DeepSort/checkpoints/yolo4-416/variables

# %%
# !python3 save_model.py --model yolov4
# Out:
# 2021-07-20 20:18:18.690857: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-20 20:18:20.253391: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-07-20 20:18:20.264472: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-07-20 20:18:20.264513: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (7697df02a280): /proc/driver/nvidia/version does not exist
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 416, 416, 3) 0
# ...

# %%
# !python3 object_tracker.py --video data/video/drone.mp4 --output /content/out.avi --model yolov4 --dont_show
# Out:
# Frame #:  1
# FPS: 0.26
# Frame #:  2
# FPS: 0.44
# Frame #:  3
# FPS: 0.43
# Frame #:  4
# FPS: 0.44
# Frame #:  5
# FPS: 0.44
# Frame #:  6
# FPS: 0.43
# Frame #:  7
# FPS: 0.44
# Frame #:  8
# FPS: 0.44
# Frame #:  9
# FPS: 0.44
# Frame #:  10
# FPS: 0.44
# Frame #:  11
# FPS: 0.44
# Frame #:  12
# FPS: 0.44
# Frame #:  13
# FPS: 0.45
# Frame #:  14
# FPS: 0.45
# Frame #:  15
# FPS: 0.45
# Frame #:  16
# FPS: 0.44
# Frame #:  17
# FPS: 0.44
# Frame #:  18
# FPS: 0.45
# Frame #:  19
# FPS: 0.44
# Frame #:  20
# FPS: 0.45
# Frame #:  21
# FPS: 0.44
# Frame #:  22
# FPS: 0.44
# Frame #:  23
# FPS: 0.44
# Frame #:  24
# FPS: 0.44
# Frame #:  25
# FPS: 0.45
# Frame #:  26
# FPS: 0.45
# Frame #:  27
# FPS: 0.46
# Frame #:  28
# FPS: 0.45
# Frame #:  29
# FPS: 0.45
# Frame #:  30
# FPS: 0.44
# Frame #:  31
# FPS: 0.45
# Frame #:  32
# FPS: 0.45
# Frame #:  33
# FPS: 0.45
# Frame #:  34
# FPS: 0.46
# Frame #:  35
# FPS: 0.45
# Frame #:  36
# FPS: 0.45
# Frame #:  37
# FPS: 0.46
# ...

# %% [markdown]
# Download the Output
# Video and Watch
